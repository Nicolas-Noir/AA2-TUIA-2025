# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolas-Noir/AA2-TUIA-2025/blob/main/Practica/AA2_lab1_10_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Perceptrón con Fuerza Bruta y Montecarlo

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FCEIA-AAII/lab1/blob/main/lab1.ipynb)

# %% [markdown]
# ## Preparación del entorno.
#
# Si no estamos parados en el repo, clonar y cd al repo. Esto nos permite usar el mismo notebook tanto local como en Google Colab.

# %%
import os

REPO_NAME = "lab1"
if REPO_NAME not in os.getcwd():
  if not os.path.exists(REPO_NAME):
    # !git clone https://github.com/FCEIA-AAII/{REPO_NAME}.git
  os.chdir(REPO_NAME)

# %% [markdown]
# ## Análisis Exploratorio.

# %% [markdown]
# Importar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Cargar y visualizar los datos.

# %%
data = pd.read_csv('dataset-lab1.csv')
print(data.head())
# Out:
#          X1        X2    Y
# 0  0.142131  0.845482  0.0
# 1  0.869759  0.708864  1.0
# 2  0.238923  0.919601  0.0
# 3  0.268460  0.431270  0.0
# 4  0.922154  0.470211  1.0

# %% [markdown]
# Plot de los datos.

# %%
X1 = data['X1'].to_numpy()
X2 = data['X2'].to_numpy()
Y = data['Y'].to_numpy()

print("X1 shape:", X1.shape)
print("X2 shape:", X2.shape)
print("Y shape:", Y.shape)

plt.scatter(X1[Y == 0], X2[Y == 0], color='red', alpha=0.5)
plt.scatter(X1[Y == 1], X2[Y == 1], color='green', alpha=0.5)

plt.xlabel('Promedio Parciales')
plt.ylabel('Promedio TPs')

plt.show()
# Out:
# X1 shape: (100,)
# X2 shape: (100,)
# Y shape: (100,)

# %% [markdown]
# Definimos la función candidata.

# %%
def perceptron(x1, x2, params):
    linear_combination = x1 * params['w1'] + x2 * params['w2'] + params['b']
    return (linear_combination >= 0) * 1

# %% [markdown]
# Definimos una función costo, por ejemplo, el error absoluto medio.

# %%
def loss(y_predicted, y_real):
    return np.mean(np.absolute(y_predicted - y_real))

# %% [markdown]
# De ahora en adelante, el objetivo es encontrar los parámetros que minimicen la función costo.
#
# Ejemplo con valores iniciales arbitrarios:

# %%
params = {
    'w1': 1,
    'w2': -1,
    'b': 0
}

y_predicted = perceptron(X1, X2, params)

print('Loss:', loss(y_predicted, Y))
# Out:
# Loss: 0.36

# %% [markdown]
# Definimos una función para plotear la frontera de decisión sobre los datos.

# %%
def plot_results(X1, X2, Y, params):
    plt.scatter(X1[Y == 0], X2[Y == 0], color='red', alpha=0.5)
    plt.scatter(X1[Y == 1], X2[Y == 1], color='green', alpha=0.5)

    plt.xlabel('Promedio Parciales')
    plt.ylabel('Promedio TPs')

    x1 = np.linspace(0, 1, 100)
    x2 = np.linspace(0, 1, 100)

    x1, x2 = np.meshgrid(x1, x2)
    y = perceptron(x1, x2, params)

    # Use cmap red and green
    plt.contourf(x1, x2, y, alpha=0.1, cmap='RdYlGn')

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.show()

plot_results(X1, X2, Y, params)

# %% [markdown]
# ## Búsqueda por fuerza bruta.
# La idea es recorrer todos los valores posibles de los parámetros y quedarnos con aquellos que minimicen la función costo.
#
# Completar el siguiente bloque con la implementación de la búsqueda por fuerza bruta:

# %%
#STEP = 0.1
#MIN = -1
#MAX = 1
#W1 = np.arange(MIN, MAX, STEP)
#W2 = np.arange(MIN, MAX, STEP)
#B = np.arange(MIN, MAX, STEP)

best_params = {
    'w1': 0,
    'w2': 0,
    'b': 0
}

best_loss = 1

# Completar el código para encontrar los mejores parámetros.
# Iterar sobre todos los valores posibles de w1, w2 y b en un loop anidado.
# En cada iteración, deberíamos hacer algo como:
# 1. Construir un diccionario con los parámetros a probar:
# params = {
#     'w1': w1,
#     'w2': w2,
#     'b': b
# }
# 2. Calcular la predicción (y_predicted) con estos parámetros.
# y_predicted = perceptron(X1, X2, params)
# 3. Calcular el loss con estos parámetros.
# l = loss(y_predicted, Y)
# 4. Si el loss es mejor que el best_loss, actualizar best_loss y best_params.

def fuerza_bruta(steps):
  best_loss = 1
  for w1 in np.arange(-1,1,steps):
    for w2 in np.arange(-1,1,steps):
      for b in np.arange(-1,1,steps):

        params = { 'w1': w1, 'w2': w2, 'b': b }

        y_predicted = perceptron(X1, X2, params)
        l = loss(y_predicted, Y)
        if l < best_loss:
          best_loss = l
          best_params = params
          print('Best loss:', best_loss)
          print('Best params:', best_params)

  return best_loss, best_params

best_loss, best_params = fuerza_bruta(0.1)

print('Best loss:', best_loss)
print('Best params:', best_params)

plot_results(X1, X2, Y, best_params)
# Out:
# Best loss: 0.43
# Best params: {'w1': -1.0, 'w2': -1.0, 'b': -1.0}
# Best loss: 0.42
# Best params: {'w1': -0.20000000000000018, 'w2': 0.6999999999999997, 'b': -0.30000000000000016}
# Best loss: 0.41
# Best params: {'w1': -0.1000000000000002, 'w2': 0.5999999999999996, 'b': -0.30000000000000016}
# Best loss: 0.38
# Best params: {'w1': -0.1000000000000002, 'w2': 0.6999999999999997, 'b': -0.30000000000000016}
# Best loss: 0.37
# Best params: {'w1': -0.1000000000000002, 'w2': 0.8999999999999995, 'b': -0.40000000000000013}
# Best loss: 0.36
# Best params: {'w1': -2.220446049250313e-16, 'w2': 0.19999999999999973, 'b': -0.1000000000000002}
# Best loss: 0.15
# Best params: {'w1': 0.09999999999999964, 'w2': 0.09999999999999964, 'b': -0.1000000000000002}
# Best loss: 0.09
# Best params: {'w1': 0.19999999999999973, 'w2': -2.220446049250313e-16, 'b': -0.1000000000000002}
# Best loss: 0.01
# Best params: {'w1': 0.2999999999999998, 'w2': 0.09999999999999964, 'b': -0.20000000000000018}
# Best loss: 0.0
# Best params: {'w1': 0.3999999999999997, 'w2': 0.19999999999999973, 'b': -0.30000000000000016}
# Best loss: 0.0
# Best params: {'w1': 0.3999999999999997, 'w2': 0.19999999999999973, 'b': -0.30000000000000016}

# %% [markdown]
# ## Método Monte Carlo.
# La idea es generar valores aleatorios para los parámetros y quedarse con el que minimiza la función costo.
# Completar el siguiente bloque con la implementación del método Monte Carlo:

# %%
best_loss = 1
best_params = {
    'w1': 0,
    'w2': 0,
    'b': 0
}

ITERATIONS = 10000

# Completar el código para encontrar los mejores parámetros.
# Realizar un loop de ITERATIONS iteraciones.
# En cada iteración, deberíamos hacer algo como:
# 1. Construir un diccionario con los parámetros a probar. Usar np.random.uniform para generar valores aleatorios.
# 2. Calcular la predicción (y_predicted) con estos parámetros.
# y_predicted = perceptron(X1, X2, params)
# 3. Calcular el loss con estos parámetros.
# l = loss(y_predicted, Y)
# 4. Si el loss es mejor que el best_loss, actualizar best_loss y best_params.

def casino_carlos():
  best_params = {
    'w1': 0,
    'w2': 0,
    'b': 0
}
  best_loss = 1
  iterations = 0
  while iterations != 10000:

    w1 = np.random.uniform(-1,1)
    w2 = np.random.uniform(-1,1)
    b = np.random.uniform(-1,1)

    params = { 'w1': w1, 'w2': w2, 'b': b }

    y_predicted = perceptron(X1, X2, params)
    l = loss(y_predicted, Y)
    if l < best_loss:
      best_loss = l
      best_params = params
      print('Best loss:', best_loss)
      print('Best params:', best_params)

    iterations += 1
  return best_loss, best_params

best_loss, best_params = casino_carlos()

print('Best loss:', best_loss)
print('Best params:', best_params)

plot_results(X1, X2, Y, best_params)
# Out:
# Best loss: 0.57
# Best params: {'w1': 0.5469307826189613, 'w2': 0.9527242326290335, 'b': -0.1584947443888316}
# Best loss: 0.43
# Best params: {'w1': -0.7827166641527037, 'w2': 0.460551021043885, 'b': -0.42391351203160044}
# Best loss: 0.4
# Best params: {'w1': -0.05369491825194794, 'w2': 0.3515573855742127, 'b': -0.16283259878310385}
# Best loss: 0.36
# Best params: {'w1': 0.7273100513132746, 'w2': -0.9918008834674052, 'b': -0.1705744857085143}
# Best loss: 0.3
# Best params: {'w1': 0.9252317256275966, 'w2': -0.6133427133578082, 'b': -0.2131893322500238}
# Best loss: 0.24
# Best params: {'w1': 0.25865631408129186, 'w2': 0.3623644567016102, 'b': -0.3393772840064053}
# Best loss: 0.1
# Best params: {'w1': 0.44808191273515874, 'w2': 0.3427177247289639, 'b': -0.3813428971063888}
# Best loss: 0.04
# Best params: {'w1': 0.4758507661633693, 'w2': 0.31539768224706033, 'b': -0.40576002707796155}
# Best loss: 0.03
# Best params: {'w1': 0.8175680877226348, 'w2': 0.3464533560297518, 'b': -0.5405308980135166}
# Best loss: 0.02
# Best params: {'w1': 0.9882433802054689, 'w2': 0.3936337041567577, 'b': -0.6644579600908107}
# Best loss: 0.0
# Best params: {'w1': 0.9271693320505403, 'w2': 0.391874598959131, 'b': -0.6624143340249642}
# Best loss: 0.0
# Best params: {'w1': 0.9271693320505403, 'w2': 0.391874598959131, 'b': -0.6624143340249642}
